# %%
#import packages and libraries

import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("train.csv")
df.head()
# Out:
#    Unnamed: 0      id  Gender      Customer Type  Age   Type of Travel  \
# 0           0   70172    Male     Loyal Customer   13  Personal Travel
# 1           1    5047    Male  disloyal Customer   25  Business travel
# 2           2  110028  Female     Loyal Customer   26  Business travel
# 3           3   24026  Female     Loyal Customer   25  Business travel
# 4           4  119299    Male     Loyal Customer   61  Business travel
#
#       Class  Flight Distance  Inflight wifi service  \
# 0  Eco Plus              460                      3
# 1  Business              235                      3
# 2  Business             1142                      2
# 3  Business              562                      2
# 4  Business              214                      3
#
#    Departure/Arrival time convenient  ...  Inflight entertainment  \
# 0                                  4  ...                       5
# 1                                  2  ...                       1
# ...

# %%
df.drop(['Unnamed: 0', 'id'], axis = 1, inplace = True)

# %%
df.head()
# Out:
#    Gender      Customer Type  Age   Type of Travel     Class  Flight Distance  \
# 0    Male     Loyal Customer   13  Personal Travel  Eco Plus              460
# 1    Male  disloyal Customer   25  Business travel  Business              235
# 2  Female     Loyal Customer   26  Business travel  Business             1142
# 3  Female     Loyal Customer   25  Business travel  Business              562
# 4    Male     Loyal Customer   61  Business travel  Business              214
#
#    Inflight wifi service  Departure/Arrival time convenient  \
# 0                      3                                  4
# 1                      3                                  2
# 2                      2                                  2
# 3                      2                                  5
# 4                      3                                  3
#
#    Ease of Online booking  Gate location  ...  Inflight entertainment  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 103904 entries, 0 to 103903
# Data columns (total 23 columns):
#  #   Column                             Non-Null Count   Dtype
# ---  ------                             --------------   -----
#  0   Gender                             103904 non-null  object
#  1   Customer Type                      103904 non-null  object
#  2   Age                                103904 non-null  int64
#  3   Type of Travel                     103904 non-null  object
#  4   Class                              103904 non-null  object
#  5   Flight Distance                    103904 non-null  int64
#  6   Inflight wifi service              103904 non-null  int64
#  7   Departure/Arrival time convenient  103904 non-null  int64
#  8   Ease of Online booking             103904 non-null  int64
#  9   Gate location                      103904 non-null  int64
#  10  Food and drink                     103904 non-null  int64
# ...

# %%
df.shape
# Out:
# (103904, 23)

# %%
df.describe()
# Out:
#                  Age  Flight Distance  Inflight wifi service  \
# count  103904.000000    103904.000000          103904.000000
# mean       39.379706      1189.448375               2.729683
# std        15.114964       997.147281               1.327829
# min         7.000000        31.000000               0.000000
# 25%        27.000000       414.000000               2.000000
# 50%        40.000000       843.000000               3.000000
# 75%        51.000000      1743.000000               4.000000
# max        85.000000      4983.000000               5.000000
#
#        Departure/Arrival time convenient  Ease of Online booking  \
# count                      103904.000000           103904.000000
# mean                            3.060296                2.756901
# std                             1.525075                1.398929
# min                             0.000000                0.000000
# 25%                             2.000000                2.000000
# ...

# %%
df.isna().sum()
# Out:
# Gender                                 0
# Customer Type                          0
# Age                                    0
# Type of Travel                         0
# Class                                  0
# Flight Distance                        0
# Inflight wifi service                  0
# Departure/Arrival time convenient      0
# Ease of Online booking                 0
# Gate location                          0
# Food and drink                         0
# Online boarding                        0
# Seat comfort                           0
# Inflight entertainment                 0
# On-board service                       0
# Leg room service                       0
# Baggage handling                       0
# Checkin service                        0
# Inflight service                       0
# Cleanliness                            0
# Departure Delay in Minutes             0
# Arrival Delay in Minutes             310
# satisfaction                           0
# ...

# %%
sns.scatterplot(data = df, x = 'Departure Delay in Minutes', y = 'Arrival Delay in Minutes')
# Out:
# <AxesSubplot:xlabel='Departure Delay in Minutes', ylabel='Arrival Delay in Minutes'>

# %%
df1 = df.copy()

df1['Arrival Delay in Minutes'] = df1['Arrival Delay in Minutes'].fillna(df1['Departure Delay in Minutes'])

df1.head()
# Out:
#    Gender      Customer Type  Age   Type of Travel     Class  Flight Distance  \
# 0    Male     Loyal Customer   13  Personal Travel  Eco Plus              460
# 1    Male  disloyal Customer   25  Business travel  Business              235
# 2  Female     Loyal Customer   26  Business travel  Business             1142
# 3  Female     Loyal Customer   25  Business travel  Business              562
# 4    Male     Loyal Customer   61  Business travel  Business              214
#
#    Inflight wifi service  Departure/Arrival time convenient  \
# 0                      3                                  4
# 1                      3                                  2
# 2                      2                                  2
# 3                      2                                  5
# 4                      3                                  3
#
#    Ease of Online booking  Gate location  ...  Inflight entertainment  \
# ...

# %%
df1.isna().sum()
# Out:
# Gender                               0
# Customer Type                        0
# Age                                  0
# Type of Travel                       0
# Class                                0
# Flight Distance                      0
# Inflight wifi service                0
# Departure/Arrival time convenient    0
# Ease of Online booking               0
# Gate location                        0
# Food and drink                       0
# Online boarding                      0
# Seat comfort                         0
# Inflight entertainment               0
# On-board service                     0
# Leg room service                     0
# Baggage handling                     0
# Checkin service                      0
# Inflight service                     0
# Cleanliness                          0
# Departure Delay in Minutes           0
# Arrival Delay in Minutes             0
# satisfaction                         0
# dtype: int64

# %%
df1.shape
# Out:
# (103904, 23)

# %%
df1.columns
# Out:
# Index(['Gender', 'Customer Type', 'Age', 'Type of Travel', 'Class',
#        'Flight Distance', 'Inflight wifi service',
#        'Departure/Arrival time convenient', 'Ease of Online booking',
#        'Gate location', 'Food and drink', 'Online boarding', 'Seat comfort',
#        'Inflight entertainment', 'On-board service', 'Leg room service',
#        'Baggage handling', 'Checkin service', 'Inflight service',
#        'Cleanliness', 'Departure Delay in Minutes', 'Arrival Delay in Minutes',
#        'satisfaction'],
#       dtype='object')

# %%
print(df1['satisfaction'].value_counts())
print()

print(df1['satisfaction'].value_counts(normalize = True))
# Out:
# neutral or dissatisfied    58879
# satisfied                  45025
# Name: satisfaction, dtype: int64
#
# neutral or dissatisfied    0.566667
# satisfied                  0.433333
# Name: satisfaction, dtype: float64

# %%
sns.countplot(x = 'satisfaction', data = df1, hue = 'satisfaction')
# Out:
# <AxesSubplot:xlabel='satisfaction', ylabel='count'>

# %%
plt.pie(df1['satisfaction'].value_counts(), labels = ['neutral or dissatisfied', 'satisfied'], explode=[0, 0.05], 
        autopct='%1.2f%%', 
        shadow = True )

plt.title("Satisfied Vs Dissatisfied Customers")
# Out:
# Text(0.5, 1.0, 'Satisfied Vs Dissatisfied Customers')

# %%
df1.hist(figsize = (20,20))
plt.show()

# %%
sns.distplot(df1['Age'])
plt.title("Age Distribution")
plt.show()
# Out:
# C:\Users\deepa\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
plt.figure(figsize = (20,8))

sns.countplot(data = df1, x = 'Age', hue = 'satisfaction')

plt.title("Age Distribution", fontsize = 20)

#plt.tight_layout()
plt.show()

# %%
cat_features = ['Gender', 'Customer Type', 'Type of Travel', 'Class', 'satisfaction']

for i in cat_features:
    
    plt.pie(df1[i].value_counts(), autopct = '%1.2f%%', labels = df1[i].value_counts().index, shadow = True)
    
    plt.title(i, fontsize = 15)
    
    plt.show()

# %%
plt.figure(figsize = (20,8))

sns.histplot(data = df1, x = 'Flight Distance', hue = 'satisfaction')
# Out:
# <AxesSubplot:xlabel='Flight Distance', ylabel='Count'>

# %%
sns.catplot(x = 'satisfaction', y = 'Flight Distance', data = df1, hue = 'satisfaction', kind = 'bar')

plt.title("Flight Distance and Customer Satisfaction", fontsize = 15)
# Out:
# Text(0.5, 1.0, 'Flight Distance and Customer Satisfaction')

# %%
sns.catplot(x = 'satisfaction', y = 'Flight Distance', hue = 'satisfaction', col = 'Class', data = df1, kind = 'bar')

#plt.title("Flight Class and Customer Satisfaction")

# %%
df1_labels = df1[['Gender', 'Customer Type', 'Type of Travel', 'Class',
       'Inflight wifi service',
       'Departure/Arrival time convenient', 'Ease of Online booking',
       'Gate location', 'Food and drink', 'Online boarding', 'Seat comfort',
       'Inflight entertainment', 'On-board service', 'Leg room service',
       'Baggage handling', 'Checkin service', 'Inflight service',
       'Cleanliness']]

labels = ['Gender', 'Customer Type', 'Type of Travel', 'Class',
       'Inflight wifi service',
       'Departure/Arrival time convenient', 'Ease of Online booking',
       'Gate location', 'Food and drink', 'Online boarding', 'Seat comfort',
       'Inflight entertainment', 'On-board service', 'Leg room service',
       'Baggage handling', 'Checkin service', 'Inflight service',
       'Cleanliness']

for label in labels:
    
    sns.countplot(x = label, data = df1_labels)
    plt.show()
    print(df1[label].value_counts())
# Out:
# Female    52727
# Male      51177
# Name: Gender, dtype: int64
# Loyal Customer       84923
# disloyal Customer    18981
# Name: Customer Type, dtype: int64
# Business travel    71655
# Personal Travel    32249
# Name: Type of Travel, dtype: int64
# Business    49665
# Eco         46745
# Eco Plus     7494
# Name: Class, dtype: int64
# 3    25868
# 2    25830
# 4    19794
# 1    17840
# 5    11469
# 0     3103
# Name: Inflight wifi service, dtype: int64
# 4    25546
# 5    22403
# 3    17966
# 2    17191
# 1    15498
# 0     5300
# Name: Departure/Arrival time convenient, dtype: int64
# 3    24449
# 2    24021
# 4    19571
# 1    17525
# 5    13851
# 0     4487
# Name: Ease of Online booking, dtype: int64
# 3    28577
# 4    24426
# 2    19459
# 1    17562
# 5    13879
# 0        1
# Name: Gate location, dtype: int64
# 4    24359
# 5    22313
# 3    22300
# 2    21988
# 1    12837
# 0      107
# Name: Food and drink, dtype: int64
# 4    30762
# 3    21804
# 5    20713
# 2    17505
# ...

# %%
labels = ['Gender', 'Customer Type', 'Type of Travel', 'Class',
       'Inflight wifi service',
       'Departure/Arrival time convenient', 'Ease of Online booking',
       'Gate location', 'Food and drink', 'Online boarding', 'Seat comfort',
       'Inflight entertainment', 'On-board service', 'Leg room service',
       'Baggage handling', 'Checkin service', 'Inflight service',
       'Cleanliness']

for label in labels:
    
    sns.countplot(x = label, data = df1, hue = 'satisfaction')
    plt.show()
    print(df1[label].value_counts())
# Out:
# Female    52727
# Male      51177
# Name: Gender, dtype: int64
# Loyal Customer       84923
# disloyal Customer    18981
# Name: Customer Type, dtype: int64
# Business travel    71655
# Personal Travel    32249
# Name: Type of Travel, dtype: int64
# Business    49665
# Eco         46745
# Eco Plus     7494
# Name: Class, dtype: int64
# 3    25868
# 2    25830
# 4    19794
# 1    17840
# 5    11469
# 0     3103
# Name: Inflight wifi service, dtype: int64
# 4    25546
# 5    22403
# 3    17966
# 2    17191
# 1    15498
# 0     5300
# Name: Departure/Arrival time convenient, dtype: int64
# 3    24449
# 2    24021
# 4    19571
# 1    17525
# 5    13851
# 0     4487
# Name: Ease of Online booking, dtype: int64
# 3    28577
# 4    24426
# 2    19459
# 1    17562
# 5    13879
# 0        1
# Name: Gate location, dtype: int64
# 4    24359
# 5    22313
# 3    22300
# 2    21988
# 1    12837
# 0      107
# Name: Food and drink, dtype: int64
# 4    30762
# 3    21804
# 5    20713
# 2    17505
# ...

# %%
#Boxplot for Continuous variable

cont = df1[['Flight Distance', 'Departure Delay in Minutes', 'Arrival Delay in Minutes']]

cont_df = pd.DataFrame(cont)

#cont_df

for n in cont_df:
    
    sns.boxplot(x = n, data = cont_df)
    
    plt.show()
    
    print(cont_df[n].value_counts())
# Out:
# 337     660
# 594     395
# 404     392
# 862     369
# 2475    369
#        ...
# 656       1
# 1364      1
# 887       1
# 1206      1
# 400       1
# Name: Flight Distance, Length: 3802, dtype: int64
# 0      58668
# 1       2948
# 2       2274
# 3       2009
# 4       1854
#        ...
# 426        1
# 465        1
# 321        1
# 692        1
# 337        1
# Name: Departure Delay in Minutes, Length: 446, dtype: int64
# 0.0      58275
# 1.0       2220
# 2.0       2072
# 3.0       1955
# 4.0       1916
#          ...
# 291.0        1
# 458.0        1
# 729.0        1
# 382.0        1
# 369.0        1
# Name: Arrival Delay in Minutes, Length: 456, dtype: int64

# %%
#Boxplot for discrete variables

import seaborn as sns


labels = ['Age', 'Inflight wifi service',
       'Departure/Arrival time convenient', 'Ease of Online booking',
       'Gate location', 'Food and drink', 'Online boarding', 'Seat comfort',
       'Inflight entertainment', 'On-board service', 'Leg room service',
       'Baggage handling', 'Checkin service', 'Inflight service',
       'Cleanliness']

for label in labels:
    sns.boxplot(x=label,data=df1)
    plt.show()

    print(df1[label].value_counts())
# Out:
# 39    2969
# 25    2798
# 40    2574
# 44    2482
# 42    2457
#       ...
# 74      47
# 76      45
# 79      42
# 78      33
# 85      17
# Name: Age, Length: 75, dtype: int64
# 3    25868
# 2    25830
# 4    19794
# 1    17840
# 5    11469
# 0     3103
# Name: Inflight wifi service, dtype: int64
# 4    25546
# 5    22403
# 3    17966
# 2    17191
# 1    15498
# 0     5300
# Name: Departure/Arrival time convenient, dtype: int64
# 3    24449
# 2    24021
# 4    19571
# 1    17525
# 5    13851
# 0     4487
# Name: Ease of Online booking, dtype: int64
# 3    28577
# 4    24426
# 2    19459
# 1    17562
# 5    13879
# 0        1
# Name: Gate location, dtype: int64
# 4    24359
# 5    22313
# 3    22300
# 2    21988
# 1    12837
# 0      107
# Name: Food and drink, dtype: int64
# 4    30762
# 3    21804
# 5    20713
# 2    17505
# 1    10692
# 0     2428
# Name: Online boarding, dtype: int64
# 4    31765
# 5    26470
# 3    18696
# 2    14897
# 1    12075
# 0        1
# ...

# %%
#Machine Learning

df2 = df1.copy()
df2.head()
# Out:
#    Gender      Customer Type  Age   Type of Travel     Class  Flight Distance  \
# 0    Male     Loyal Customer   13  Personal Travel  Eco Plus              460
# 1    Male  disloyal Customer   25  Business travel  Business              235
# 2  Female     Loyal Customer   26  Business travel  Business             1142
# 3  Female     Loyal Customer   25  Business travel  Business              562
# 4    Male     Loyal Customer   61  Business travel  Business              214
#
#    Inflight wifi service  Departure/Arrival time convenient  \
# 0                      3                                  4
# 1                      3                                  2
# 2                      2                                  2
# 3                      2                                  5
# 4                      3                                  3
#
#    Ease of Online booking  Gate location  ...  Inflight entertainment  \
# ...

# %%
df2.shape
# Out:
# (103904, 23)

# %%
#Data Preprocessing

#Label encoding

from sklearn.preprocessing import LabelEncoder

label_encoder = LabelEncoder()

for col in df2.select_dtypes(include = ['object']).columns:
    
    df2[col] = label_encoder.fit_transform(df2[col])

# %%
df2.head()
# Out:
#    Gender  Customer Type  Age  Type of Travel  Class  Flight Distance  \
# 0       1              0   13               1      2              460
# 1       1              1   25               0      0              235
# 2       0              0   26               0      0             1142
# 3       0              0   25               0      0              562
# 4       1              0   61               0      0              214
#
#    Inflight wifi service  Departure/Arrival time convenient  \
# 0                      3                                  4
# 1                      3                                  2
# 2                      2                                  2
# 3                      2                                  5
# 4                      3                                  3
#
#    Ease of Online booking  Gate location  ...  Inflight entertainment  \
# 0                       3              1  ...                       5
# ...

# %%
df2.shape
# Out:
# (103904, 23)

# %%
#Removing Outliers

Q1 = df2.quantile(0.25)
Q3 = df2.quantile(0.75)

iqr = Q3  - Q1

print(iqr)
# Out:
# Gender                                  1.0
# Customer Type                           0.0
# Age                                    24.0
# Type of Travel                          1.0
# Class                                   1.0
# Flight Distance                      1329.0
# Inflight wifi service                   2.0
# Departure/Arrival time convenient       2.0
# Ease of Online booking                  2.0
# Gate location                           2.0
# Food and drink                          2.0
# Online boarding                         2.0
# Seat comfort                            3.0
# Inflight entertainment                  2.0
# On-board service                        2.0
# Leg room service                        2.0
# Baggage handling                        2.0
# Checkin service                         1.0
# Inflight service                        2.0
# Cleanliness                             2.0
# Departure Delay in Minutes             12.0
# ...

# %%
upper_limit = Q3 + 1.5 * iqr
lower_limit = Q1 - 1.5 * iqr

outliers = df2[(df2 > upper_limit) | (df2 < lower_limit)]

print(len(outliers))

print(outliers.shape)
# Out:
# 103904
# (103904, 23)

# %%
non_outlier = df2[(df2 >= lower_limit) & (df2 <= upper_limit)]

print(len(non_outlier))
# Out:
# 103904

# %%
train = df2[~((df2 < lower_limit) |(df2 > upper_limit)).any(axis=1)]
train.shape
# Out:
# (61197, 23)

# %%
#Correlation among features

plt.figure(figsize = (20,10))

sns.heatmap(train.corr(), annot = True)
# Out:
# <AxesSubplot:>

# %%
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler()

scaler.fit(train)

data = pd.DataFrame(scaler.transform(train), columns = train.columns)

# %%
data.head()
# Out:
#    Gender  Customer Type       Age  Type of Travel  Class  Flight Distance  \
# 0     1.0            0.0  0.076923             1.0    1.0         0.115789
# 1     0.0            0.0  0.243590             0.0    0.0         0.299865
# 2     1.0            0.0  0.692308             0.0    0.0         0.049393
# 3     0.0            0.0  0.243590             1.0    0.5         0.310121
# 4     1.0            0.0  0.512821             1.0    0.5         0.336032
#
#    Inflight wifi service  Departure/Arrival time convenient  \
# 0                    0.6                                0.8
# 1                    0.4                                0.4
# 2                    0.6                                0.6
# 3                    0.6                                0.8
# 4                    0.4                                0.8
#
#    Ease of Online booking  Gate location  ...  Inflight entertainment  \
# 0                     0.6            0.2  ...                     1.0
# ...

# %%
#Machine learning models

from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier

import sklearn.metrics as metrics

from sklearn.metrics import precision_score, recall_score, accuracy_score, f1_score, \
roc_auc_score, confusion_matrix, ConfusionMatrixDisplay, classification_report, roc_curve

from xgboost import XGBClassifier
from xgboost import XGBRegressor
from xgboost import plot_importance

from sklearn.tree import plot_tree

# %%
y = data['satisfaction']

X = data.drop('satisfaction', axis = 1)

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.20, stratify = y, random_state = 42)

# %%
#Logistic Regression

log_clf = LogisticRegression(random_state = 42, max_iter = 500)

log_clf.fit(X_train, y_train)
# Out:
# LogisticRegression(max_iter=500, random_state=42)

# %%
log_pred = log_clf.predict(X_test)

# %%
log_cm = confusion_matrix(y_test, log_pred, labels = log_clf.classes_)

log_disp = ConfusionMatrixDisplay(log_cm, display_labels = log_clf.classes_)

log_disp.plot(values_format = '')

plt.show()

# %%
target_names = ['Predicted Customer not satisfied', 'Predicted Customer satisfied']

print(classification_report(y_test, log_pred,target_names = target_names))
# Out:
#                                   precision    recall  f1-score   support
#
# Predicted Customer not satisfied       0.87      0.90      0.89      5998
#     Predicted Customer satisfied       0.90      0.87      0.89      6242
#
#                         accuracy                           0.89     12240
#                        macro avg       0.89      0.89      0.89     12240
#                     weighted avg       0.89      0.89      0.89     12240

# %%
log_pred_proba = log_clf.predict_proba(X_test)[::,1]
fpr, tpr,_ = metrics.roc_curve(y_test, log_pred_proba)
auc = metrics.roc_auc_score(y_test, log_pred_proba)
plt.plot(fpr,tpr,label="ROC curve auc="+str(auc), color='darkorange')
plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
plt.legend(loc=4)

plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.title("Receiver Operating Characteristic (ROC) curve")
plt.show()

# %%
#Decision Tree

# Instantiate model
tree = DecisionTreeClassifier(random_state=0)

# Assign a dictionary of hyperparameters to search over
cv_params = {'max_depth': [12],
             'max_features' : ["sqrt"]
             }

# Assign a dictionary of scoring metrics to capture
scoring = {'accuracy', 'precision', 'recall', 'f1', 'roc_auc'}

# Instantiate GridSearch
tree1 = GridSearchCV(tree, cv_params, scoring=scoring, cv=4, refit='roc_auc')

# %%
# %%time
tree1.fit(X_train, y_train)
# Out:
# Wall time: 1.13 s
# GridSearchCV(cv=4, estimator=DecisionTreeClassifier(random_state=0),
#              param_grid={'max_depth': [12], 'max_features': ['sqrt']},
#              refit='roc_auc',
#              scoring={'roc_auc', 'precision', 'accuracy', 'f1', 'recall'})

# %%
tree1.best_params_
# Out:
# {'max_depth': 12, 'max_features': 'sqrt'}

# %%
tree1.best_score_
# Out:
# 0.9758386654196607

# %%
tree_pred = tree1.predict(X_test)

# %%
target_names = ['Predicted Customer not satisfied', 'Predicted Customer satisfied']

print(classification_report(y_test, tree_pred, target_names = target_names))
# Out:
#                                   precision    recall  f1-score   support
#
# Predicted Customer not satisfied       0.92      0.95      0.93      5998
#     Predicted Customer satisfied       0.95      0.92      0.93      6242
#
#                         accuracy                           0.93     12240
#                        macro avg       0.93      0.93      0.93     12240
#                     weighted avg       0.93      0.93      0.93     12240

# %%
tree_cm = confusion_matrix(y_test, tree_pred, labels = tree1.classes_)

tree_disp = ConfusionMatrixDisplay(tree_cm, display_labels = tree1.classes_)

tree_disp.plot(values_format = '')

plt.title("Confusion Matrix")

plt.show()

# %%
tree_pred_proba = tree1.predict_proba(X_test)[::,1]
fpr, tpr,_ = metrics.roc_curve(y_test, tree_pred_proba)
auc = metrics.roc_auc_score(y_test, tree_pred_proba)
plt.plot(fpr,tpr,label="ROC curve auc="+str(auc), color='darkorange')
plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
plt.legend(loc=4)

plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.title("Receiver Operating Characteristic (ROC) curve")
plt.show()

# %%
#Random Forest

# Instantiate model
rf = RandomForestClassifier(random_state=0)

# Assign a dictionary of hyperparameters to search over
cv_params = {'max_depth': [16], 
             'min_samples_leaf': [1],
             'min_samples_split': [2],
             'n_estimators': [100],
             }  

# Assign a dictionary of scoring metrics to capture
scoring = {'accuracy', 'precision', 'recall', 'f1', 'roc_auc'}

# Instantiate GridSearch
rf1 = GridSearchCV(rf, cv_params, scoring=scoring, cv=4, refit='roc_auc')

# %%
# %%time
rf1.fit(X_train, y_train) # --> Wall time: ~10min
# Out:
# Wall time: 59.4 s
# GridSearchCV(cv=4, estimator=RandomForestClassifier(random_state=0),
#              param_grid={'max_depth': [16], 'min_samples_leaf': [1],
#                          'min_samples_split': [2], 'n_estimators': [100]},
#              refit='roc_auc',
#              scoring={'roc_auc', 'precision', 'accuracy', 'f1', 'recall'})

# %%
rf1.best_score_
# Out:
# 0.9950736832318192

# %%
rf1.best_params_
# Out:
# {'max_depth': 16,
#  'min_samples_leaf': 1,
#  'min_samples_split': 2,
#  'n_estimators': 100}

# %%
rf_pred = rf1.predict(X_test)

# %%
target_names = ['Predicted Customer not satisfied', 'Predicted Customer satisfied']

print(classification_report(y_test, rf_pred, target_names = target_names))
# Out:
#                                   precision    recall  f1-score   support
#
# Predicted Customer not satisfied       0.95      0.98      0.96      5998
#     Predicted Customer satisfied       0.98      0.95      0.96      6242
#
#                         accuracy                           0.96     12240
#                        macro avg       0.96      0.96      0.96     12240
#                     weighted avg       0.96      0.96      0.96     12240

# %%
rf_cm = confusion_matrix(y_test, rf_pred, labels = rf1.classes_)

rf_disp = ConfusionMatrixDisplay(rf_cm, display_labels = rf1.classes_)

rf_disp.plot(values_format = '')

plt.title("Confusion Matrix")

plt.show()

# %%
rf_pred_prob = rf1.predict_proba(X_test)[::,1]
fpr,tpr,_ = metrics.roc_curve(y_test, rf_pred_prob)
auc = metrics.roc_auc_score(y_test, rf_pred_prob)

plt.plot(fpr,tpr, label = "ROC curve auc = "+str(auc), color = 'darkorange')
plt.plot([0,1], [0,1], color = 'navy', ls = '--', lw = 2)

plt.title("Receiver Operating Characteristic Curve")
plt.xlabel("True Positive Rate")
plt.ylabel("False Positive Rate")

plt.legend(loc = 4)

plt.show()

# %%
#XGBoost

import xgboost as xgb

xgb = XGBClassifier()

cv_params = {'n_estimators' : [100],
            'max_depth' : [10]
            }

scoring = {'accuracy', 'precision', 'recall', 'f1', 'roc_auc'}

xgb1 = GridSearchCV(xgb, cv_params, scoring = scoring, cv =4, refit = 'roc_auc')

# %%
xgb1.fit(X_train, y_train)
# Out:
# GridSearchCV(cv=4,
#              estimator=XGBClassifier(base_score=None, booster=None,
#                                      callbacks=None, colsample_bylevel=None,
#                                      colsample_bynode=None,
#                                      colsample_bytree=None, device=None,
#                                      early_stopping_rounds=None,
#                                      enable_categorical=False, eval_metric=None,
#                                      feature_types=None, gamma=None,
#                                      grow_policy=None, importance_type=None,
#                                      interaction_constraints=None,
#                                      learning_rate=None,...
#                                      max_cat_to_onehot=None,
#                                      max_delta_step=None, max_depth=None,
#                                      max_leaves=None, min_child_weight=None,
# ...

# %%
xgb1.best_score_
# Out:
# 0.9962643168237914

# %%
xgb1.best_params_
# Out:
# {'max_depth': 10, 'n_estimators': 100}

# %%
xgb_pred = xgb1.predict(X_test)

# %%
target_names = ['Predicted Customer not satisfied', 'Predicted Customer satisfied']

print(classification_report(y_test, xgb_pred, target_names = target_names))
# Out:
#                                   precision    recall  f1-score   support
#
# Predicted Customer not satisfied       0.95      0.98      0.96      5998
#     Predicted Customer satisfied       0.98      0.95      0.96      6242
#
#                         accuracy                           0.96     12240
#                        macro avg       0.96      0.96      0.96     12240
#                     weighted avg       0.96      0.96      0.96     12240

# %%
xgb_cm = confusion_matrix(y_test, xgb_pred, labels = xgb1.classes_)

xgb_disp = ConfusionMatrixDisplay(xgb_cm, display_labels = xgb1.classes_)

xgb_disp.plot(values_format = '')

plt.title("Confusion Matrix")

plt.show()

# %%
xgb_pred_prob = xgb1.predict_proba(X_test)[::,1]
fpr, tpr, _ = metrics.roc_curve(y_test, xgb_pred_prob)
auc = metrics.roc_auc_score(y_test, xgb_pred_prob)

plt.plot(fpr,tpr, label = "ROC curve auc = "+str(auc), color = 'darkorange')
plt.plot([0,1], [0,1], lw = 2, ls = '--')

plt.title("Receiver Operating Characteristic(ROC) curve")

plt.legend(loc = 4)

plt.show()

# %%
def make_results(model_name:str, model_object, metric:str):
    '''
    Arguments:
        model_name (string): what you want the model to be called in the output table
        model_object: a fit GridSearchCV object
        metric (string): precision, recall, f1, accuracy, or auc
  
    Returns a pandas df with the F1, recall, precision, accuracy, and auc scores
    for the model with the best mean 'metric' score across all validation folds.  
    '''

    # Create dictionary that maps input metric to actual metric name in GridSearchCV
    metric_dict = {'auc': 'mean_test_roc_auc',
                   'precision': 'mean_test_precision',
                   'recall': 'mean_test_recall',
                   'f1': 'mean_test_f1',
                   'accuracy': 'mean_test_accuracy'
                  }

    # Get all the results from the CV and put them in a df
    cv_results = pd.DataFrame(model_object.cv_results_)

    # Isolate the row of the df with the max(metric) score
    best_estimator_results = cv_results.iloc[cv_results[metric_dict[metric]].idxmax(), :]

    # Extract Accuracy, precision, recall, and f1 score from that row
    auc = best_estimator_results.mean_test_roc_auc
    f1 = best_estimator_results.mean_test_f1
    recall = best_estimator_results.mean_test_recall
    precision = best_estimator_results.mean_test_precision
    accuracy = best_estimator_results.mean_test_accuracy
  
    # Create table of results
    table = pd.DataFrame()
    table = pd.DataFrame({'model': [model_name],
                          'precision': [precision],
                          'recall': [recall],
                          'F1': [f1],
                          'accuracy': [accuracy],
                          'auc': [auc]
                        })
  
    return table

# %%
results = make_results('Decision Tree', tree1, 'auc')

#log_result = make_results('Logistic Regression', log_clf, 'auc')

rf_result = make_results('Random Forest', rf1, 'auc')

xgb_result = make_results('XGBoostClassifier', xgb1, 'auc')

results = pd.concat([results, rf_result, xgb_result], axis = 0, ignore_index = True)
results
# Out:
#                model  precision    recall        F1  accuracy       auc
# 0      Decision Tree   0.955066  0.929939  0.942323  0.941949  0.975839
# 1      Random Forest   0.977477  0.954374  0.965784  0.965521  0.995074
# 2  XGBoostClassifier   0.977561  0.957859  0.967607  0.967298  0.996264

# %%
#def get_results(model_name:str, model_object):
    
log_acc = metrics.accuracy_score(y_test, log_pred)
tree_acc = metrics.accuracy_score(y_test, tree_pred)
rf_acc = metrics.accuracy_score(y_test, rf_pred)
xgb_acc = metrics.accuracy_score(y_test, xgb_pred)

log_precision = metrics.precision_score(y_test, log_pred)
tree_precision = metrics.precision_score(y_test, tree_pred)
rf_precision = metrics.precision_score(y_test, rf_pred)
xgb_precision = metrics.precision_score(y_test, xgb_pred)

log_recall = metrics.recall_score(y_test, log_pred)
tree_recall = metrics.recall_score(y_test, tree_pred)
rf_recall = metrics.recall_score(y_test, rf_pred)
xgb_recall = metrics.recall_score(y_test, xgb_pred)

log_f1 = metrics.f1_score(y_test, log_pred)
tree_f1 = metrics.f1_score(y_test, tree_pred)
rf_f1 = metrics.f1_score(y_test, rf_pred)
xgb_f1 = metrics.f1_score(y_test, xgb_pred)

log_roc_auc = metrics.roc_auc_score(y_test, log_pred_proba)
tree_roc_auc = metrics.roc_auc_score(y_test, tree_pred_proba)
rf_roc_auc = metrics.roc_auc_score(y_test, rf_pred_prob)
xgb_roc_auc = metrics.roc_auc_score(y_test, xgb_pred_prob)


accuracy_scores = [log_acc, tree_acc, rf_acc, xgb_acc]
precision_score = [log_precision, tree_precision, rf_precision, xgb_precision]
recall_score = [log_recall, tree_recall, rf_recall, xgb_recall]
f1_score = [log_f1, tree_f1, rf_f1, xgb_f1]
roc_auc_score = [log_roc_auc, tree_roc_auc, rf_roc_auc, xgb_roc_auc]



model_names = ['Logistic Regression', 'Decision Tree', 'Random Forest', 'XGBoostClassifier']

model_data = {'Model' : model_names,
             'Accuracy' : accuracy_scores,
             'Precision' : precision_score,
              'Recall' : recall_score,
              'F1' : f1_score,
              'ROC AUC' : roc_auc_score
             }

data = pd.DataFrame(model_data)

data['Accuracy'] = (data['Accuracy'] * 100)
data['Precision'] = (data['Precision'] * 100)
data['Recall'] = (data['Recall'] * 100)
data['F1'] = (data['F1'] * 100)
data['ROC AUC'] = (data['ROC AUC'] * 100)


data
# Out:
#                  Model   Accuracy  Precision     Recall         F1    ROC AUC
# 0  Logistic Regression  88.602941  89.998350  87.359821  88.659459  94.229551
# 1        Decision Tree  93.406863  95.058863  91.845562  93.424591  97.808589
# 2        Random Forest  96.388889  98.140770  94.713233  96.396543  99.483671
# 3    XGBoostClassifier  96.356209  97.948379  94.841397  96.369852  99.584613

# %%
def get_test_scores(model_name:str, preds, y_test_data):
    '''
    Generate a table of test scores.

    In:
    model_name (string): Your choice: how the model will be named in the output table
    preds: numpy array of test predictions
    y_test_data: numpy array of y_test data

    Out:
    table: a pandas df of precision, recall, f1, and accuracy scores for your model
    '''
    accuracy = metrics.accuracy_score(y_test_data, preds)
    precision = metrics.precision_score(y_test_data, preds)
    recall = metrics.recall_score(y_test_data, preds)
    f1 = metrics.f1_score(y_test_data, preds)

    table = pd.DataFrame({'model': [model_name],
                        'precision': [precision],
                        'recall': [recall],
                        'F1': [f1],
                        'accuracy': [accuracy]
                        })

    return table

# %%
log_res = get_test_scores('Logistic Regression', log_pred, y_test)
tree_res = get_test_scores('Decision Tree', tree_pred, y_test)
rf_res = get_test_scores('Random Forest', rf_pred, y_test)
xgb_res = get_test_scores('XGBoost Classifier', xgb_pred, y_test)

log_res = pd.concat([log_res,tree_res,rf_res,xgb_res], axis = 0, ignore_index = True)
log_res
# Out:
#                  model  precision    recall        F1  accuracy
# 0  Logistic Regression   0.899983  0.873598  0.886595  0.886029
# 1        Decision Tree   0.950589  0.918456  0.934246  0.934069
# 2        Random Forest   0.981408  0.947132  0.963965  0.963889
# 3   XGBoost Classifier   0.979484  0.948414  0.963699  0.963562
